# %%
import boto3
import json

bedrock = boto3.client('bedrock-runtime', region_name='us-east-1')
model_id = 'amazon.nova-micro-v1:0'

payload = {
    "messages": [
        {
            "role": "user",
            "content": [
                {
                    "text": "Tell me what type of dances people do."
                }
            ]
        }
    ]
}

payload_json = json.dumps(payload)

response = bedrock.invoke_model_with_response_stream(
    modelId=model_id,
    body=payload_json,
    contentType='application/json',
    accept='application/json'
)

stream = response['body']
full_text = ""

print("Receiving response stream:")
for event in stream:
    chunk = event['chunk']
    chunk_str = chunk.get('bytes', b'').decode('utf-8')

    try:
        json_chunk = json.loads(chunk_str)

        if "contentBlockDelta" in json_chunk:
            delta = json_chunk["contentBlockDelta"]["delta"]
            text = delta.get("text", "")
            full_text += text
            print(text, end='') 

    except json.JSONDecodeError:
        continue
# Out:
# Receiving response stream:
# There are numerous types of dances that people perform around the world, each with its own unique style, history, and cultural significance. Here are some of the most popular types of dances:
#
# ### **Social Dances**
# These are typically performed in casual settings and are often enjoyed by people of all ages.
#
# 1. **Salsa**
#    - Origin: Latin America
#    - Characteristics: Fast-paced, energetic, and often performed in pairs.
#
# 2. **Tango**
#    - Origin: Argentina
#    - Characteristics: Sensual and dramatic, often performed with close body contact.
#
# 3. **Waltz**
#    - Origin: Austria/Germany
#    - Characteristics: Slow, graceful, and typically performed in triple time.
#
# 4. **Foxtrot**
#    - Origin: United States
#    - Characteristics: Smooth and flowing, often performed in a gentle manner.
#
# 5. **Cha-Cha**
#    - Origin: Cuba
#    - Characteristics: Upbeat and lively, often performed with a lot of hip action.
#
# ### **Folk Dances**
# These dances are traditional and often reflect the cultural heritage of a particular region or community.
#
# 1. **Irish Dance**
#    - Origin: Ireland
#    - Characteristics: Energetic and often includes the use of a small, hard shoe called a ghillie boot.
#
# 2. **Flamenco**
#    - Origin: Spain
#    - Characteristics: Intense and passionate, often includes singing, guitar playing, and dance.
#
# 3. **Bhangra**
#    - Origin: Punjab, India
#    - Characteristics: High-energy and often performed with traditional Punjabi dress and instruments.
#
# 4. **Polka**
#    - Origin: Czech Republic
#    - Characteristics: Fast-paced and lively, often performed in a quick tempo.
#
# 5. **Square Dance**
#    - Origin: United States
#    - Characteristics: Social dance where participants form a square with partners and follow a series of calls.
#
# ### **Ballroom Dances**
# These are formal dances typically performed in competitions and social events.
#
# 1. **Tango**
#    - (Also listed under Social Dances)
#
# 2. **Viennese Waltz**
#    - Origin: Austria
#    - Characteristics: Smooth and elegant, often performed with long, flowing movements.
#
# 3. **Rumba**
#    - Origin: Cuba
#    - Characteristics: Sensual and romantic, often performed with a lot of hip action.
#
# 4. **Samba**
#    - Origin: Brazil
#    - Characteristics: Energetic and lively, often performed with a lot of hip movement.
#
# 5. **Paso Doble**
#    - Origin: Spain
#    - Characteristics: Dramatic and theatrical, often depicting a bullfight.
#
# ### **Contemporary Dances**
# These are modern styles that blend various elements from different dance forms.
#
# 1. **Hip-Hop**
#    - Origin: United States
#    - Characteristics: Street dance style with a lot of rhythmic movement and often includes breakdancing.
#
# 2. **Contemporary**
#    - Characteristics: Combines elements of ballet, modern dance, and other styles, focusing on expressive movements.
#
# 3. **Jazz Dance**
#    - Origin: United States
#    - Characteristics: Energetic and often includes a lot of kicks, leaps, and turns.
#
# 4. **Lyrical Dance**
#    - Characteristics: Combines elements of contemporary and ballet, focusing on storytelling through movement.
#
# ### **Religious and Ritual Dances**
# These dances often have spiritual or ceremonial significance.
#
# 1. **Bhakti Dance**
#    - Origin: India
#    - Characteristics: Devotional dance performed to express love and devotion to a deity.
#
# 2. **Native American Dance**
#    - Origin: Various tribes in North America
#    - Characteristics: Often performed in ceremonies and rituals, often includes storytelling and spiritual significance.
#
# 3. **Hallelujah Dance**
#    - Origin: Various religious communities
#    - Characteristics: Spontaneous dance of praise and worship.
#
# ### **Performance Dances**
# These dances are often performed in theaters or on stage.
#
# 1. **Ballet**
#    - Origin: Italy/France
#    - Characteristics: Highly formalized and often includes intricate footwork, graceful movements, and dramatic storytelling.
#
# 2. **Modern Dance**
#    - Origin: United States
#    - Characteristics: Free-form and expressive, often focusing on the emotional and physical expression of the dancer.
#
# 3. **Tap Dance**
#    - Origin: United States
#    - Characteristics: Rhythmic dance performed with tap shoes, often includes intricate footwork and musicality.
#
# Each type of dance offers a unique way to express culture, emotion, and creativity.
